# %% [markdown]
# <a href="https://colab.research.google.com/github/kkettip/datasci_1_loading/blob/main/datasci_1_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Excel**

# %%
import pandas as pd

# %% [markdown]
# Lists the average price of apples per pound and per cup.

# %%
df1 = pd.read_excel('/content/Apples 2020.xlsx')
df1.head(n=10)
# Out:
#   Apples—Average retail price per pound or pint and per cup equivalent, 2020  \
# 0                                               Form
# 1                                             Fresh1
# 2                                        Applesauce2
# 3                                              Juice
# 4                                    Ready to drink3
# 5                                            Frozen4
# 6  1The USDA National Nutrient Database for Stand...
# 7  2Excludes applesauce packed in individual cont...
# 8  3Includes refrigerated and unrefrigerated juice.
# 9  4Includes juice sold as frozen concentrate. Th...
#
#               Unnamed: 1  Unnamed: 2                Unnamed: 3  \
# 0  Average retail price          NaN  Preparation yield factor
# 1               1.519329   per pound                       0.9
# 2               1.066033   per pound                         1
# 3                    NaN         NaN                       NaN
# ...

# %%
df1.columns
# Out:
# Index(['Apples—Average retail price per pound or pint and per cup equivalent, 2020',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %% [markdown]
# Lists the aver age price of bananas per pound and per cup.

# %%
df2 = pd.read_excel('/content/Bananas 2020.xlsx')
df2.head(n=10)
# Out:
#   Bananas—Average retail price per pound and per cup equivalent, 2020  \
# 0                                               Form
# 1                                             Fresh1
# 2  1The USDA National Nutrient Database for Stand...
# 3  Source: USDA, Economic Research Service calcul...
#
#               Unnamed: 1  Unnamed: 2                Unnamed: 3  \
# 0  Average retail price          NaN  Preparation yield factor
# 1               0.524896   per pound                      0.64
# 2                    NaN         NaN                       NaN
# 3                    NaN         NaN                       NaN
#
#                   Unnamed: 4 Unnamed: 5                        Unnamed: 6
# 0  Size of a cup equivalent         NaN  Average price per cup equivalent
# 1                   0.330693     pounds                          0.271218
# 2                        NaN        NaN                               NaN
# ...

# %%
df2.columns
# Out:
# Index(['Bananas—Average retail price per pound and per cup equivalent, 2020',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %% [markdown]
# Lists the average price of peaches per pound and per cup.

# %%
df3 = pd.read_excel('/content/Peaches 2020.xlsx')
df3.head(n=10)
# Out:
#   Peaches—Average retail price per pound and per cup equivalent, 2020  \
# 0                                               Form
# 1                                             Fresh1
# 2                                             Canned
# 3                                   Packed in juice2
# 4                          Packed in syrup or water3
# 5                                             Frozen
# 6  1The USDA National Nutrient Database for Stand...
# 7  2Consumers are assumed to eat the solid fruit ...
# 8  3The syrup (or water) is discarded prior to co...
# 9  Source: USDA, Economic Research Service calcul...
#
#               Unnamed: 1  Unnamed: 2                Unnamed: 3  \
# 0  Average retail price          NaN  Preparation yield factor
# 1               1.716723   per pound                      0.96
# 2                                NaN
# 3               2.023687   per pound                         1
# 4               1.811723   per pound                      0.65
# ...

# %%
df3.columns
# Out:
# Index(['Peaches—Average retail price per pound and per cup equivalent, 2020',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')

# %% [markdown]
# # **CSV**

# %% [markdown]
# Lists the average price of fruits by retail price per pound or pint and by cup.

# %%
df4 = pd.read_csv('/content/Fruit Prices 2020.csv')
df4.head(n=10)
# Out:
#                                 Fruit    Form  RetailPrice RetailPriceUnit  \
# 0                              Apples   Fresh       1.5193       per pound
# 1                  Apples, applesauce  Canned       1.0660       per pound
# 2              Apples, ready-to-drink   Juice       0.7804        per pint
# 3          Apples, frozen concentrate   Juice       0.5853        per pint
# 4                            Apricots   Fresh       2.9665       per pound
# 5           Apricots, packed in juice  Canned       1.6905       per pound
# 6  Apricots, packed in syrup or water  Canned       2.0600       per pound
# 7                            Apricots   Dried       6.6188       per pound
# 8                             Bananas   Fresh       0.5249       per pound
# 9                      Berries, mixed  Frozen       3.5585       per pound
#
#    Yield  CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# 0   0.90             0.2425            pounds              0.4094
# ...

# %%
df4.columns
# Out:
# Index(['Fruit', 'Form', 'RetailPrice', 'RetailPriceUnit', 'Yield',
#        'CupEquivalentSize', 'CupEquivalentUnit', 'CupEquivalentPrice'],
#       dtype='object')

# %% [markdown]
# Provide information on the number of unaccompanied children in HHS care.

# %%
df5 = pd.read_csv('/content/HHS_Unaccompanied_Children_Program.csv')
df5.head(n=10)
# Out:
#             Date  Children in HHS Care  Children discharged from HHS Care
# 0  March 23 2021                 11551                                209
# 1  March 24 2021                 11900                                268
# 2  March 25 2021                 12551                                280
# 3  March 28 2021                 11886                                248
# 4  March 29 2021                 12035                                229
# 5  March 30 2021                 12918                                215
# 6  March 31 2021                 13204                                244
# 7  April 01 2021                 13359                                288
# 8  April 04 2021                 14287                                242
# 9  April 05 2021                 15193                                239

# %%
df5.columns
# Out:
# Index(['Date', 'Children in HHS Care', 'Children discharged from HHS Care'], dtype='object')

# %% [markdown]
# Provides information on the Monkeypox research, status, country and organization conducting the research.

# %%
df6 = pd.read_csv('/content/Monkeypox_Research_Summary_Data.csv')
df6.head(n=10)
# Out:
#                               Research Activity  \
# 0                  Vaccine Immunogenicity Study
# 1        Vaccine Immunogenicity Study (Vaccine)
# 2                Drug-Vaccine Interaction Study
# 3                   Vaccine Effectiveness Study
# 4  Vaccine Effectiveness Case Series Evaluation
# 5                     Vaccine Utilization Study
# 6                   Vaccine Safety Surveillance
# 7                  Vaccine Immunogenicity Study
# 8                      Novel Vaccine Evaluation
# 9              Next Generation Vaccine Research
#
#   Project Title \n(and link to additional information, if available)    Topic  \
# 0  A Multicenter Trial Evaluating Alterative Dosi...                  Vaccine
# 1  A Multicenter Trial Evaluating Alterative Dosi...                  Vaccine
# 2  Study to evaluate the immunogenicity profile a...                  Vaccine
# 3  National estimates of post-licensure vaccine p...                  Vaccine
# ...

# %%
df6.columns
# Out:
# Index(['Research Activity',
#        'Project Title \n(and link to additional information, if available)',
#        'Topic', 'Agency and Office Name',
#        'Country(ies) in which research is/will be conducted', 'Status',
#        'Upcoming Milestones', 'Anticipated Completion', 'Brief Description',
#        'Project Link'],
#       dtype='object')

# %% [markdown]
# # **Json**

# %% [markdown]
# Provides information on state, age, sex, condition, hosipital readmission rate, ER visits, and whether individual has medicare or medicaid or both.

# %%
url = 'https://data.cms.gov/data-api/v1/dataset/60ccbf1c-d3f5-4354-86a3-465711d81c5a/data'
df7 = pd.read_json(url)
df7.head(n=10)
# Out:
#   Bene_Geo_Lvl Bene_Geo_Desc  Bene_Geo_Cd Bene_Age_Lvl Bene_Demo_Lvl  \
# 0        State       Alabama            1          All           All
# 1        State       Alabama            1          65+   Dual Status
# 2        State       Alabama            1          <65   Dual Status
# 3        State       Alabama            1          All   Dual Status
# 4        State       Alabama            1          65+   Dual Status
# 5        State       Alabama            1          <65   Dual Status
# 6        State       Alabama            1          All   Dual Status
# 7        State       Alabama            1          65+           Sex
# 8        State       Alabama            1          <65           Sex
# 9        State       Alabama            1          All           Sex
#
#           Bene_Demo_Desc      Bene_Cond  Prvlnc Tot_Mdcr_Stdzd_Pymt_PC  \
# 0                    All  Alcohol Abuse  0.0188             25102.3405
# 1          Medicare Only  Alcohol Abuse  0.0118
# ...

# %%
df7.columns
# Out:
# Index(['Bene_Geo_Lvl', 'Bene_Geo_Desc', 'Bene_Geo_Cd', 'Bene_Age_Lvl',
#        'Bene_Demo_Lvl', 'Bene_Demo_Desc', 'Bene_Cond', 'Prvlnc',
#        'Tot_Mdcr_Stdzd_Pymt_PC', 'Tot_Mdcr_Pymt_PC', 'Hosp_Readmsn_Rate',
#        'ER_Visits_Per_1000_Benes'],
#       dtype='object')

# %% [markdown]
# Provides information on Opioid Treatment Program Medicare providers that includes address, provider name, medicare effective date and phone number of provider.

# %%
df8 = pd.read_json('/content/OTP_dataset.json')
df8.head(n=10)
# Out:
#                      NPI                        PROVIDER NAME  \
# 0  1003081399 1013055110  BAART BEHAVIORAL HEALTH SERVICES IN
# 1             1003150004                 AMS OF WISCONSIN LLC
# 2             1003362484                         BHG XLII LLC
# 3             1003368945                         RTS EDGEWOOD
# 4             1003571647        METRO TREATMENT OF FLORIDA LP
# 5  1003581174 1326713314            PREMIER CARE OF OHIO, LLC
# 6             1003583733  AFFINITY HEALTHCARE GROUP CHERRY HI
# 7             1003947193  WEST TEXAS COUNSELING & REHABILITAT
# 8             1003953548             ALLIANCE RECOVERY CENTER
# 9             1003953548             ALLIANCE RECOVERY CENTER
#
#               ADDRESS LINE 1                  ADDRESS LINE 2            CITY  \
# 0            617 COMSTOCK RD                           STE 5          BERLIN
# 1      9532 E 16 FRONTAGE RD                         STE 100        ONALASKA
# ...

# %%
df8.columns
# Out:
# Index(['NPI', 'PROVIDER NAME', 'ADDRESS LINE 1', 'ADDRESS LINE 2', 'CITY',
#        'STATE', 'ZIP', 'MEDICARE ID EFFECTIVE DATE', 'PHONE'],
#       dtype='object')

# %% [markdown]
# Provides information on inpatient discharges for Medicare Part A individuals that includes provider name, payment amounts, provider state and city, and hospital charges.

# %%
df9 = pd.read_json('/content/Medicare_Inpatient.json')
df9.head(n=10)
# Out:
#    Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name Rndrng_Prvdr_City  \
# 0             10001  Southeast Health Medical Center            Dothan
# 1             10001  Southeast Health Medical Center            Dothan
# 2             10001  Southeast Health Medical Center            Dothan
# 3             10001  Southeast Health Medical Center            Dothan
# 4             10001  Southeast Health Medical Center            Dothan
# 5             10001  Southeast Health Medical Center            Dothan
# 6             10001  Southeast Health Medical Center            Dothan
# 7             10001  Southeast Health Medical Center            Dothan
# 8             10001  Southeast Health Medical Center            Dothan
# 9             10001  Southeast Health Medical Center            Dothan
#
#           Rndrng_Prvdr_St  Rndrng_Prvdr_State_FIPS  Rndrng_Prvdr_Zip5  \
# 0  1108 Ross Clark Circle                        1              36301
# ...

# %%
df9.columns
# Out:
# Index(['Rndrng_Prvdr_CCN', 'Rndrng_Prvdr_Org_Name', 'Rndrng_Prvdr_City',
#        'Rndrng_Prvdr_St', 'Rndrng_Prvdr_State_FIPS', 'Rndrng_Prvdr_Zip5',
#        'Rndrng_Prvdr_State_Abrvtn', 'Rndrng_Prvdr_RUCA',
#        'Rndrng_Prvdr_RUCA_Desc', 'DRG_Cd', 'DRG_Desc', 'Tot_Dschrgs',
#        'Avg_Submtd_Cvrd_Chrg', 'Avg_Tot_Pymt_Amt', 'Avg_Mdcr_Pymt_Amt'],
#       dtype='object')
